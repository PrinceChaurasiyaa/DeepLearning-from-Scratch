# %%
from SinglePerceptronScratch.ipynb import SinglePerceptron
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from SinglePerceptronScratch.ipynb import SinglePerceptron
#
# ModuleNotFoundError: No module named 'SinglePerceptronScratch'
